# %% [markdown]
# # Major data formats in the weather radar world
#
#
# - CFRadial
# - ODIM
# - Rainbow
# - Nexrad

# %% [markdown]
# # [CFRadial](https://www.eol.ucar.edu/system/files/CfRadialDoc-v2.0-20180430.pdf)
#
# *Py-ART Radar object inherits CFRadial data structure*
#
# - Based on NetCDF
# - For **polar** radar coordinates only
# - De-facto standard for the research community
# - Standard format at WMO for radial weather data
# - some CRFRadial readers: [ωradlib](https://docs.wradlib.org/en/stable/generated/wradlib.io.backends.CfRadial1BackendEntrypoint.html), [Py-ART](https://arm-doe.github.io/pyart/API/generated/pyart.io.read_cfradial.html)

# %% [markdown]
# ## CFRadial hierarchical data structure
#
# ![data_structure_cfradial.png](attachment:data_structure_cfradial.png)

# %% [markdown]
# # [ODIM](https://www.eumetnet.eu/wp-content/uploads/2019/01/ODIM_H5_v23.pdf)
#
# - OPERA (Europe weather radar cooperation) standard
# - Based on HDF5
# - Can be used for polar and Cartesian data
# - some ODIM readers: [ωradlib](https://docs.wradlib.org/en/stable/generated/wradlib.io.hdf.open_odim_mfdataset.html), [Py-ART](https://arm-doe.github.io/pyart/API/generated/pyart.aux_io.read_odim_h5.html)

# %% [markdown]
# ## ODIM data structure
#
# <div>
# <img style="float: left;" src="attachment:ODIM_structure.png" width="600">
# </div>
# <div style="float: left; font-size: 20pt">
#
# - **How** : All instrument and acquisition parameters
# - **Where** : e.g. WGS coordinates, range, azimuth (polar), grid size (Cartesian)
# - **What** :
#    - at top-level: type of data (PVOL, CVOL,...), institution, file format
#    - at dataset-level: product name, quantity, gain, offset
#
# </div>

# %% [markdown]
# # Rainbow
#
# - Proprietary format used by the company &nbsp; <img style="float: right; margin-right: 20%;" src="https://upload.wikimedia.org/wikipedia/commons/d/da/Logo_Leonardo.png" width = 150>
# - Output of Leonardo (prev. Selex) radars, e.g. Germany, Switzerland
# - Non-standard binary file
# - some ODIM readers: [ωradlib](https://docs.wradlib.org/en/stable/generated/wradlib.io.rainbow.read_rainbow.html), [Py-ART](https://arm-doe.github.io/pyart/API/generated/pyart.aux_io.read_rainbow_wrl.html)

# %% [markdown]
# # Nexrad
#
# <img style="margin-left: auto; margin-right: auto;" src="https://wx.erau.edu/faculty/mullerb/Wx365/NEXRAD/WSR-88DCONUSCoverage2011.jpg" width = 30%>
#
#
# - Data from the Next Generation Weather Radar (Nexrad) network in the US (160 S-band radars)
# - This data is easily available so format is often encountered
# - some Nexrad readers [Py-ART](http://arm-doe.github.io/pyart/API/generated/pyart.io.read_nexrad_level3.html), [RSL](https://trmm-fc.gsfc.nasa.gov/trmm_gv/software/rsl/).
